# %%
# mounting google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# accessing the code files using a shared folder in google drive
# %cd drive/MyDrive/EE782/instagan
# Out:
# /content/drive/.shortcut-targets-by-id/17HUmPOOfHSQHfQat3VeS6BmiI_JgupJq/instagan

# %%
# installing required libraries
# !pip install -r requirements.txt -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 26.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !pip install Pillow==6.2.2 -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.8/37.8 MB 20.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bokeh 3.3.1 requires pillow>=7.1.0, but you have pillow 6.2.2 which is incompatible.
# dopamine-rl 4.0.6 requires Pillow>=7.0.0, but you have pillow 6.2.2 which is incompatible.
# fastai 2.7.13 requires pillow>=9.0.0, but you have pillow 6.2.2 which is incompatible.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 6.2.2 which is incompatible.

# %%
# !mkdir /content/COCO

# downloading the dataset
# !wget http://images.cocodataset.org/annotations/annotations_trainval2017.zip -P /content/COCO
# !wget http://images.cocodataset.org/zips/train2017.zip -P /content/COCO
# !wget http://images.cocodataset.org/zips/val2017.zip -P /content/COCO
# !wget http://images.cocodataset.org/zips/test2017.zip -P /content/COCO

# extracting files
# !unzip /content/COCO/annotations_trainval2017.zip -d /content/COCO
# !rm /content/COCO/annotations_trainval2017.zip

# !unzip /content/COCO/train2017.zip -d /content/COCO
# !rm /content/COCO/train2017.zip

# !unzip /content/COCO/val2017.zip -d /content/COCO
# !rm /content/COCO/val2017.zip

# !unzip /content/COCO/test2017.zip -d /content/COCO
# !rm /content/COCO/test2017.zip

# %%
# getting the horse2zebra dataset and preparing the directory structure required for running instagan
# !python ./datasets/generate_coco_dataset.py --data_root /content/COCO/ --save_root ./datasets/horse2zebra --cat1 horse --cat2 zebra

# %%
# training instagan
# !python train.py --niter 25 --niter_decay 25 --display_id -1 --dataroot ./datasets/horse2zebra --model insta_gan --name instagan_50 --loadSizeH 220 --loadSizeW 220 --fineSizeH 200 --fineSizeW 200 --display_freq 100 --update_html_freq 100 --print_freq 10 --save_latest_freq 100 --save_epoch_freq 1
# Out:
# ----------------- Options ---------------
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                  dataroot: ./datasets/horse2zebra        	[default: None]
#              dataset_mode: unaligned_seg
#                 direction: AtoB
#               display_env: main
#              display_freq: 100                           	[default: 400]
#                display_id: -1                            	[default: 1]
#             display_ncols: 6
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 1
#                 fineSizeH: 200
#                 fineSizeW: 200
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   ins_max: 4
#                   ins_per: 2
# ...

# %%
# testing instagan
# !python test.py --eval --dataroot ./datasets/horse2zebra --model insta_gan --name instagan_50 --loadSizeH 200 --loadSizeW 200 --fineSizeH 200 --fineSizeW 200 --ins_per 2 --ins_max 20 --phase train
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                  dataroot: ./datasets/horse2zebra        	[default: None]
#              dataset_mode: unaligned_seg
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: True                          	[default: False]
#                 fineSizeH: 200
#                 fineSizeW: 200
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   ins_max: 20                            	[default: 4]
#                   ins_per: 2
#                   isTrain: False                         	[default: None]
#                  loadSize: None
#                 loadSizeH: 200                           	[default: 220]
# ...
